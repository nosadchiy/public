# %% [markdown]
# <a href="https://colab.research.google.com/github/nosadchiy/public/blob/main/ValueIteration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## (s, S) Policy Computation Script

# %%
import numpy as np

# ----------------------------
# PARAMETERS
# ----------------------------
# Fixed ordering cost and per-unit cost
K = 10.0         # fixed ordering cost
c = 2.0          # unit ordering cost

# Holding cost and penalty (shortage) cost
h = 1.0          # holding cost per unit
p = 20.0         # penalty cost per unit

# Discount factor
beta = 0.95

# State space: inventory levels 0,1,...,X_max
X_max = 30
states = np.arange(X_max+1)

# Action space: possible order quantities 0,1,...,Q_max
Q_max = 30
actions = np.arange(Q_max+1)

# ----------------------------
# DEMAND DISTRIBUTION
# ----------------------------
# We use a demand distribution over {0,...,d_max} that puts more weight on higher demand values.
d_max = 10
# For example, these probabilities favor higher demand:
P_d = np.array([0.005, 0.005, 0.01, 0.03, 0.05, 0.1, 0.15, 0.2, 0.2, 0.15, 0.1])
# Normalize (should already sum to 1)
P_d = P_d / np.sum(P_d)
d_vals = np.arange(d_max+1)

# ----------------------------
# VALUE ITERATION PARAMETERS
# ----------------------------
tol = 1e-5    # convergence tolerance
max_iter = 1000

# Initialize value function and policy arrays
V = np.zeros(len(states))
policy = np.zeros(len(states), dtype=int)

# ----------------------------
# VALUE ITERATION ALGORITHM
# ----------------------------
for it in range(max_iter):
    V_new = np.zeros_like(V)
    delta = 0.0
    for ix, x in enumerate(states):
        action_costs = []
        for q in actions:
            # Ordering cost: fixed cost (if q > 0) plus per-unit cost
            cost_order = (K if q > 0 else 0.0) + c * q
            exp_cost = 0.0
            for d, prob in zip(d_vals, P_d):
                inv_after = x + q - d  # inventory after demand
                if inv_after >= 0:
                    cost_inventory = h * inv_after
                    next_state = min(int(inv_after), X_max)
                else:
                    cost_inventory = p * (-inv_after)
                    next_state = 0  # lost sales: next period starts with 0 inventory
                exp_cost += prob * (cost_inventory + beta * V[next_state])
            total_cost = cost_order + exp_cost
            action_costs.append(total_cost)
        best_cost = min(action_costs)
        best_action = actions[np.argmin(action_costs)]
        V_new[ix] = best_cost
        policy[ix] = best_action
        delta = max(delta, abs(V_new[ix] - V[ix]))
    V = V_new.copy()
    if delta < tol:
        print(f"Value iteration converged in {it+1} iterations.")
        break
else:
    print("Value iteration did not converge within the maximum number of iterations.")

# ----------------------------
# OUTPUT RESULTS
# ----------------------------
print("\nOptimal Policy (order quantity) for each inventory level:")
for x, q in enumerate(policy):
    print(f"Inventory level {x:2d} -> Order {q:2d} units")
# Out:
# Value iteration converged in 290 iterations.
#
# Optimal Policy (order quantity) for each inventory level:
# Inventory level  0 -> Order 10 units
# Inventory level  1 -> Order  9 units
# Inventory level  2 -> Order  8 units
# Inventory level  3 -> Order  7 units
# Inventory level  4 -> Order  6 units
# Inventory level  5 -> Order  5 units
# Inventory level  6 -> Order  4 units
# Inventory level  7 -> Order  3 units
# Inventory level  8 -> Order  0 units
# Inventory level  9 -> Order  0 units
# Inventory level 10 -> Order  0 units
# Inventory level 11 -> Order  0 units
# Inventory level 12 -> Order  0 units
# Inventory level 13 -> Order  0 units
# Inventory level 14 -> Order  0 units
# Inventory level 15 -> Order  0 units
# Inventory level 16 -> Order  0 units
# Inventory level 17 -> Order  0 units
# Inventory level 18 -> Order  0 units
# Inventory level 19 -> Order  0 units
# Inventory level 20 -> Order  0 units
# Inventory level 21 -> Order  0 units
# Inventory level 22 -> Order  0 units
# Inventory level 23 -> Order  0 units
# Inventory level 24 -> Order  0 units
# Inventory level 25 -> Order  0 units
# Inventory level 26 -> Order  0 units
# Inventory level 27 -> Order  0 units
# Inventory level 28 -> Order  0 units
# Inventory level 29 -> Order  0 units
# Inventory level 30 -> Order  0 units

# %% [markdown]
# # Task
# Refactor the inventory optimization value iteration code into a reusable Python function that computes the optimal (s, S) policy parameters for a given fixed ordering cost 'K'. Use this function to calculate the (s, S) parameters for fixed costs K = [0, 10, 20], and then create a plot showing how the reorder point 's' and the order-up-to level 'S' change as the cost 'K' increases. Summarize the observed relationship between ordering costs and these policy thresholds.

# %%
def get_s_S_policy(K=20.0, c=2.0, h=1.0, p=20.0, beta=0.95, X_max=30, Q_max=30, tol=1e-5, max_iter=1000):
    """
    Refactors value iteration to find the (s, S) policy parameters.
    Returns (s, S) where s is the reorder point and S is the target level.
    """
    states = np.arange(X_max + 1)
    actions = np.arange(Q_max + 1)
    d_max = 10
    P_d = np.array([0.005, 0.005, 0.01, 0.03, 0.05, 0.1, 0.15, 0.2, 0.2, 0.15, 0.1])
    P_d = P_d / np.sum(P_d)
    d_vals = np.arange(d_max + 1)

    V = np.zeros(len(states))
    policy = np.zeros(len(states), dtype=int)

    for it in range(max_iter):
        V_new = np.zeros_like(V)
        delta = 0.0
        for ix, x in enumerate(states):
            action_costs = []
            for q in actions:
                cost_order = (K if q > 0 else 0.0) + c * q
                exp_cost = 0.0
                for d, prob in zip(d_vals, P_d):
                    inv_after = x + q - d
                    if inv_after >= 0:
                        cost_inventory = h * inv_after
                        next_state = min(int(inv_after), X_max)
                    else:
                        cost_inventory = p * (-inv_after)
                        next_state = 0
                    exp_cost += prob * (cost_inventory + beta * V[next_state])
                action_costs.append(cost_order + exp_cost)

            best_cost = min(action_costs)
            best_action = actions[np.argmin(action_costs)]
            V_new[ix] = best_cost
            policy[ix] = best_action
            delta = max(delta, abs(V_new[ix] - V[ix]))

        V = V_new.copy()
        if delta < tol:
            break

    # Extract (s, S) parameters
    # s: highest inventory level where we still order (q > 0)
    ordering_states = np.where(policy > 0)[0]
    if len(ordering_states) > 0:
        s = np.max(ordering_states)
        # S: target inventory level (inventory + order quantity)
        # We take the target level from the state where we order (e.g., state 0)
        S = 0 + policy[0]
    else:
        s, S = None, None

    return {"s": s, "S": S}

# %% [markdown]
# ## Compute (s, S) for Multiple K Values

# %%
K_values = [0, 5, 10, 15, 20, 25, 30]
s_values = []
S_values = []

print(f"{'K':<5} | {'s':<5} | {'S':<5}")
print("-" * 20)

for K_val in K_values:
    policy_params = get_s_S_policy(K=K_val)
    s_val = policy_params['s']
    S_val = policy_params['S']

    s_values.append(s_val)
    S_values.append(S_val)

    print(f"{K_val:<5} | {s_val:<5} | {S_val:<5}")
# Out:
# K     | s     | S
# --------------------
# 0     | 9     | 10
# 5     | 7     | 10
# 10    | 7     | 10
# 15    | 6     | 18
# 20    | 6     | 18
# 25    | 6     | 18
# 30    | 6     | 24
#
# Extracted s values: [np.int64(9), np.int64(7), np.int64(7), np.int64(6), np.int64(6), np.int64(6), np.int64(6)]
# Extracted S values: [np.int64(10), np.int64(10), np.int64(10), np.int64(18), np.int64(18), np.int64(18), np.int64(24)]

# %% [markdown]
# ## Plot (s, S) Parameters vs K

# %%
import matplotlib.pyplot as plt

# Create the plot
plt.figure(figsize=(10, 6))
plt.plot(K_values, s_values, marker='o', linestyle='-', color='blue', label='Reorder Point (s)')
plt.plot(K_values, S_values, marker='s', linestyle='-', color='red', label='Order-up-to Level (S)')

# Add labels and title
plt.xlabel('Fixed Ordering Cost (K)')
plt.ylabel('Inventory Level')
plt.title('Impact of Fixed Ordering Cost K on (s, S) Policy')

# Add legend and grid
plt.legend()
plt.grid(True, linestyle='--', alpha=0.7)

# Display the plot
plt.show()
