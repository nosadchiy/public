# %% [markdown]
# <a href="https://colab.research.google.com/github/nosadchiy/public/blob/main/Geotagging.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install googlemaps

import googlemaps
import pandas as pd
from geopy.geocoders import GoogleV3

# Enter your own API key
# Obtain a free Google Maps API key from your Google Cloud account
# Initialize the Google Maps client with your API key
geolocator = GoogleV3(api_key='')
gmaps = googlemaps.Client(key='')

# %%
# Function to get geocode for a location
def get_geocode(location):
    coords = geolocator.geocode(location)
    lat = round(coords.latitude, 4)
    lng = round(coords.longitude, 4)
    return lat, lng

# %%
#import csv from github to dataframe
data = pd.read_csv('https://raw.githubusercontent.com/nosadchiy/public/main/address.txt', delimiter='\t')
print(data)
# Out:
#                                               address
# 0        245 SUMMER STREET, BOSTON, MA 02210-1133, US
# 1   501 COMMERCE STREET, NASHVILLE, TN 37203-0302, US
# 2    HSBC MAIN BUILDING, 1 QUEENS ROAD, HONG KONG, HK
# 3   230 WEST JACKSON BOULEVARD, CHICAGO, IL 60606-...
# 4       800 THIRD AVENUE, NEW YORK, NY 10022-7649, US
# ..                                                ...
# 94   131 SOUTH DEARBORN STREET, CHICAGO, IL 60603, US
# 95           1600 BROADWAY, DENVER, CO 80202-4000, US
# 96  2330 WEST JOPPA ROAD, LUTHERVILLE, MD 21093-72...
# 97   28 HAVEMEYER PLACE, GREENWICH, CT 10022-4382, US
# 98   1114 DELAWARE AVENUE, BUFFALO, NY 14209-1604, US
#
# [99 rows x 1 columns]

# %%
# Get geocodes for each address in the DataFrame
data[['Lat', 'Lng']] = data['address'].apply(lambda x: pd.Series(get_geocode(x)))

# %%
data
# Out:
#                                               address      Lat       Lng
# 0        245 SUMMER STREET, BOSTON, MA 02210-1133, US  42.3515  -71.0540
# 1   501 COMMERCE STREET, NASHVILLE, TN 37203-0302, US  36.1616  -86.7795
# 2    HSBC MAIN BUILDING, 1 QUEENS ROAD, HONG KONG, HK  22.2802  114.1594
# 3   230 WEST JACKSON BOULEVARD, CHICAGO, IL 60606-...  41.8783  -87.6309
# 4       800 THIRD AVENUE, NEW YORK, NY 10022-7649, US  40.7556  -73.9714
# ..                                                ...      ...       ...
# 94   131 SOUTH DEARBORN STREET, CHICAGO, IL 60603, US  41.8798  -87.6292
# 95           1600 BROADWAY, DENVER, CO 80202-4000, US  39.7392 -104.9903
# 96  2330 WEST JOPPA ROAD, LUTHERVILLE, MD 21093-72...  39.4198  -76.6668
# 97   28 HAVEMEYER PLACE, GREENWICH, CT 10022-4382, US  41.0244  -73.6236
# 98   1114 DELAWARE AVENUE, BUFFALO, NY 14209-1604, US  42.9143  -78.8700
#
# [99 rows x 3 columns]

# %%
data['Link'] = 'https://www.google.com/maps/place/' + data['Lat'].astype(str) + ',' + data['Lng'].astype(str)

def make_clickable(val):
  return '<a href="{}">{}</a>'.format(val,val)

data.style.format({'Link': make_clickable})
data
# Out:
#                                               address      Lat       Lng  \
# 0        245 SUMMER STREET, BOSTON, MA 02210-1133, US  42.3515  -71.0540
# 1   501 COMMERCE STREET, NASHVILLE, TN 37203-0302, US  36.1616  -86.7795
# 2    HSBC MAIN BUILDING, 1 QUEENS ROAD, HONG KONG, HK  22.2802  114.1594
# 3   230 WEST JACKSON BOULEVARD, CHICAGO, IL 60606-...  41.8783  -87.6309
# 4       800 THIRD AVENUE, NEW YORK, NY 10022-7649, US  40.7556  -73.9714
# ..                                                ...      ...       ...
# 94   131 SOUTH DEARBORN STREET, CHICAGO, IL 60603, US  41.8798  -87.6292
# 95           1600 BROADWAY, DENVER, CO 80202-4000, US  39.7392 -104.9903
# 96  2330 WEST JOPPA ROAD, LUTHERVILLE, MD 21093-72...  39.4198  -76.6668
# 97   28 HAVEMEYER PLACE, GREENWICH, CT 10022-4382, US  41.0244  -73.6236
# 98   1114 DELAWARE AVENUE, BUFFALO, NY 14209-1604, US  42.9143  -78.8700
#
#                                                  Link
# ...
